# %%
! pip install shapely

# %%
import os
import time
import pandas as pd
import numpy as np
from multiprocessing import Pool
import matplotlib.pyplot as plt
from scipy import stats
import re
import json
import shapely
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

import boto3
from s3fs.core import S3FileSystem

# %%
# state names and abbreviations:

names = ['Alabama',
'Arizona',
'Arkansas',
'California',
'Colorado',
'Connecticut',
'Delaware',
'DistrictofColumbia',
'Florida',
'Georgia',
'Hawaii',
'Idaho',
'Illinois',
'Indiana',
'Iowa',
'Kansas',
'Kentucky',
'Louisiana',
'Maine',
'Maryland',
'Massachusetts',
'Michigan',
'Minnesota',
'Mississippi',
'Missouri',
'Montana',
'Nebraska',
'Nevada',
'NewHampshire',
'NewJersey',
'NewMexico',
'NewYork',
'NorthCarolina',
'NorthDakota',
'Ohio',
'Oklahoma',
'Oregon',
'Pennsylvania',
'RhodeIsland',
'SouthCarolina',
'SouthDakota',
'Tennessee',
'Texas',
'Utah',
'Vermont',
'Virginia',
'Washington',
'WestVirginia',
'Wisconsin',
'Wyoming']


abbrv = ['AL',
'AZ',
'AR',
'CA',
'CO',
'CT',
'DE',
'DC',
'FL',
'GA',
'HI',
'ID',
'IL',
'IN',
'IA',
'KS',
'KY',
'LA',
'ME',
'MD',
'MA',
'MI',
'MN',
'MS',
'MO',
'MT',
'NE',
'NV',
'NH',
'NJ',
'NM',
'NY',
'NC',
'ND',
'OH',
'OK',
'OR',
'PA',
'RI',
'SC',
'SD',
'TN',
'TX',
'UT',
'VT',
'VA',
'WA',
'WV',
'WI',
'WY']

# %% [markdown]
# # Use sample spectrum output file for testing

# %%
spec_df = pd.read_csv('specMapOutput_20180101.csv')
locations = np.asarray((spec_df.latitude, spec_df.longitude)).T
locations.shape
locations[0]
# Out:
# array([ 41.9381141, -88.0906228])

# %% [markdown]
# # Take location input and find 1) the state and 2) the county:

# %% [markdown]
# Get state centers for location lookup:

# %%
s3 = boto3.resource('s3')
client = boto3.client('s3')
bucket = s3.Bucket('usa-edges-for-speed-mapping')

# %%
# Get data from s3 locally.

state_centers = np.zeros((len(names),2))
for i in range(0, len(names)):
    # path for boundary json file
    path = '/home/ec2-user/SageMaker/boundary_data/states/'+names[i]+'.json'
    json_data=open(path, 'r')
    boundary = json.load(json_data)
    state_centers[i, 0] = float(boundary['lat'])
    state_centers[i, 1] = float(boundary['lon'])

# %% [markdown]
# County boundary files:

# %%
county_files = os.listdir('/home/ec2-user/SageMaker/boundary_data/counties/')

# %%
# GET STATE GROUPS~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ 

# check time of routine:
t0 = time.time()

path_states = '/home/ec2-user/SageMaker/boundary_data/states/'
path_counties = '/home/ec2-user/SageMaker/boundary_data/counties/'

error_array1 = []
error_array2 = []
#error_array3 = []
#error_array4 = []

state_group1 = []
state_group2 = []
state_group3 = []
#group4 = []

for i in range(0, len(names)):
    try:
        # path for boundary json file
        json_data=open(path_states+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon)[0]
        #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        polygon_ar.shape[1] == 2
        state_group1.append(i)
    except:
        error_array1.append(i)
for i in error_array1:
    try:
        # path for boundary json file
        json_data=open(path_states+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        n_poly = len(polygon)
        for n in range(n_poly):
            polygon_ar = np.asarray(polygon[n])[0]
            #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            polygon_ar.shape[1] == 2
        state_group2.append(i)

    except:
        error_array2.append(i)
for i in error_array2:
    try:
        # path for boundary json file
        json_data=open(path_states+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon[0])
        polygon_ar.shape[1] == 2
        #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        state_group3.append(i)

    except:
        #error_array3.append(i)
        print('error for', names[i])
        

        
# FIND STATE/COUNTY PER INPUT LOCATION~~~~~~~~~~~~~~~~~~~~~~~~~~~~
t1 = time.time() - t0

for i in range(0, len(locations)):
    
    t2 = time.time()
    # find nearest states:
    center_diffs = abs(state_centers[:,0] - locations[i][0]) + abs(state_centers[:,1] - locations[i][1])  
    min_index = np.argmin(center_diffs)
    indices = np.argsort(center_diffs)[0:6]
    
    # Check if point is in the 4 nearst states with the nearest state centers:
    for n in indices:
        json_data=open(path_states+names[n]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        if n in state_group1:
            polygon_ar = np.asarray(polygon)[0]
        elif n in state_group2:
            if n == 16: # kentucky (n=16) has two bounded regions
                polygon_ar = np.asarray(polygon[1])[0]
            else:
                polygon_ar = np.asarray(polygon[0])[0]
        elif n in state_group3:
            polygon_ar = np.asarray(polygon[0])


        polygon_boundary = np.column_stack((polygon_ar[:,0],polygon_ar[:,1])) # Reshape coordinates
        polygon = Polygon(polygon_boundary) # create polygon
        point = Point(locations[i][1], locations[i][0]) # create point
        # check if a point is in the polygon 
        if point.within(polygon) == True:
            break

    state_polygon = polygon
    print('State confirmed as', names[n])
    
    counties = [s for s in county_files if abbrv[n] in s]

    # GIVEN THE STATE, LET'S FIND THE COUNTY:
    county_centers = np.zeros((len(counties),2))
    for j in range(0, len(counties)):
        # path for boundary json file
        json_data=open(path_counties+counties[j], 'r')
        boundary = json.load(json_data)
        county_centers[j, 0] = float(boundary['lat'])
        county_centers[j, 1] = float(boundary['lon'])
                
    error_array1 = []
    error_array2 = []
    error_array3 = []
    error_array4 = []

    group1 = []
    group2 = []
    group3 = []
    group4 = []

    for j in range(0, len(counties)):
        try:
            # path for boundary json file
            json_data=open(path_counties+counties[j], 'r')
            boundary = json.load(json_data)
            nb = len(boundary)
            if nb==2:
                for m in range(nb):
                    polygon = boundary[m]['geojson']['coordinates']
                    polygon_ar = np.asarray(polygon)[0]
                    polygon_ar.shape[1] == 2
                    #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            else:
                polygon = boundary['geojson']['coordinates']
                polygon_ar = np.asarray(polygon)[0]
                polygon_ar.shape[1] == 2
                #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group1.append(j)
        except:
            error_array1.append(j)
    for j in error_array1:
        try:
            # path for boundary json file
            json_data=open(path_counties+counties[j], 'r')
            boundary = json.load(json_data)
            num = len(boundary['geojson']['coordinates'])
            for n in range(num):
                polygon = boundary['geojson']['coordinates'][n]
                polygon_ar = np.asarray(polygon)[0]
                polygon_ar.shape[1] == 2
                #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group2.append(j)
        except:
            error_array2.append(j)
    for j in error_array2:
        try:
            # path for boundary json file
            json_data=open(path_counties+counties[j], 'r')
            boundary = json.load(json_data)
            num = len(boundary['geojson']['coordinates'])
            for n in range(num):
                polygon = boundary['geojson']['coordinates'][n]
                polygon_ar = np.asarray(polygon[0])
                polygon_ar.shape[1] == 2
                #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group3.append(j)
        except:
            error_array3.append(j)
    for j in error_array3:
        try:
            # path for boundary json file
            json_data=open(path_counties+counties[j], 'r')
            boundary = json.load(json_data)
            nb = len(boundary)
            for m in range(nb):
                polygon = boundary['geojson']['coordinates']
                polygon_ar = np.asarray(polygon[0])
                polygon_ar.shape[1] == 2
                #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group4.append(j)
        except:
            error_array4.append(j)
            
            
    # FIND COUNTY:
    # find nearest counties in state
    center_diffs = abs(county_centers[:,0] - locations[i][0]) + abs(county_centers[:,1] - locations[i][1])  
    min_index = np.argmin(center_diffs)
    indices = np.argsort(center_diffs)

    # Check if point is in the 10 nearest counties with the nearest county centers:
    for n in indices:
        json_data=open(path_counties+counties[n], 'r')
        boundary = json.load(json_data)
        if n in group1:
            polygon = boundary['geojson']['coordinates']
            polygon_ar = np.asarray(polygon)[0]
        elif n in group2:
            polygon = boundary['geojson']['coordinates'][0]
            polygon_ar = np.asarray(polygon)[0]
        elif n in group3:
            polygon = boundary['geojson']['coordinates'][0]
            polygon_ar = np.asarray(polygon[0])
        elif n in group4:
            polygon = boundary['geojson']['coordinates']
            polygon_ar = np.asarray(polygon[0])

        polygon_boundary = np.column_stack((polygon_ar[:,0],polygon_ar[:,1])) # Reshape coordinates
        polygon = Polygon(polygon_boundary) # create polygon
        point = Point(locations[i][1], locations[i][0]) # create point
        # check if a point is in the polygon 
        #print(n, counties[n])
        if point.within(polygon) == True:
            break


    print(i, n, counties[n])
    print("--- %s seconds ---" % (time.time() - t2 + t1))
# Out:
# State confirmed as Illinois
# 0 89 IL_DuPageCounty.json
# --- 0.5018954277038574 seconds ---
# State confirmed as Illinois
# 1 81 IL_CookCounty.json
# --- 0.528691291809082 seconds ---
# State confirmed as Illinois
# 2 81 IL_CookCounty.json
# --- 0.5002686977386475 seconds ---
# State confirmed as Illinois
# 3 89 IL_DuPageCounty.json
# --- 0.4990839958190918 seconds ---
# State confirmed as Illinois
# 4 89 IL_DuPageCounty.json
# --- 0.49915289878845215 seconds ---
# State confirmed as Illinois
# 5 81 IL_CookCounty.json
# --- 0.5012111663818359 seconds ---
# State confirmed as Illinois
# 6 81 IL_CookCounty.json
# --- 0.500786304473877 seconds ---
# State confirmed as Illinois
# 7 89 IL_DuPageCounty.json
# --- 0.49946093559265137 seconds ---
# State confirmed as Illinois
# 8 89 IL_DuPageCounty.json
# --- 0.4990866184234619 seconds ---
# State confirmed as Illinois
# 9 81 IL_CookCounty.json
# --- 0.500683069229126 seconds ---
# State confirmed as Illinois
# 10 89 IL_DuPageCounty.json
# --- 0.4990959167480469 seconds ---
# State confirmed as Illinois
# 11 89 IL_DuPageCounty.json
# --- 0.4993281364440918 seconds ---
# State confirmed as California
# 12 9 CA_SacramentoCounty.json
# --- 0.947465181350708 seconds ---
# State confirmed as California
# 13 9 CA_SacramentoCounty.json
# --- 0.971501350402832 seconds ---
# State confirmed as Illinois
# 14 81 IL_CookCounty.json
# --- 0.5010967254638672 seconds ---
# State confirmed as California
# 15 9 CA_SacramentoCounty.json
# --- 0.9465436935424805 seconds ---
# State confirmed as California
# 16 9 CA_SacramentoCounty.json
# --- 0.9446871280670166 seconds ---
# State confirmed as Illinois
# 17 81 IL_CookCounty.json
# --- 0.5008547306060791 seconds ---
# State confirmed as California
# 18 9 CA_SacramentoCounty.json
# --- 0.9452407360076904 seconds ---
# State confirmed as California
# 19 9 CA_SacramentoCounty.json
# --- 0.9706053733825684 seconds ---
# State confirmed as California
# 20 9 CA_SacramentoCounty.json
# --- 0.9463334083557129 seconds ---
# State confirmed as California
# 21 9 CA_SacramentoCounty.json
# --- 0.9487838745117188 seconds ---
# State confirmed as California
# 22 9 CA_SacramentoCounty.json
# --- 0.9498369693756104 seconds ---
# State confirmed as California
# 23 9 CA_SacramentoCounty.json
# --- 0.9702355861663818 seconds ---
# State confirmed as California
# 24 9 CA_SacramentoCounty.json
# --- 0.9440169334411621 seconds ---
# State confirmed as California
# 25 9 CA_SacramentoCounty.json
# --- 0.946718692779541 seconds ---
# State confirmed as California
# 26 9 CA_SacramentoCounty.json
# --- 0.9424581527709961 seconds ---
# State confirmed as California
# 27 9 CA_SacramentoCounty.json
# --- 0.9707851409912109 seconds ---
# State confirmed as California
# 28 9 CA_SacramentoCounty.json
# --- 0.9434022903442383 seconds ---
# State confirmed as California
# 29 9 CA_SacramentoCounty.json
# --- 0.9404067993164062 seconds ---
# State confirmed as California
# 30 9 CA_SacramentoCounty.json
# --- 0.9412641525268555 seconds ---
# State confirmed as California
# 31 9 CA_SacramentoCounty.json
# --- 0.9396581649780273 seconds ---
# State confirmed as California
# 32 9 CA_SacramentoCounty.json
# --- 0.9698147773742676 seconds ---
# State confirmed as California
# 33 9 CA_SacramentoCounty.json
# --- 0.9414999485015869 seconds ---
# State confirmed as California
# 34 9 CA_SacramentoCounty.json
# --- 0.9363746643066406 seconds ---
# State confirmed as California
# 35 9 CA_SacramentoCounty.json
# --- 0.9407780170440674 seconds ---
# State confirmed as California
# 36 9 CA_SacramentoCounty.json
# --- 0.9684257507324219 seconds ---
# State confirmed as California
# 37 9 CA_SacramentoCounty.json
# --- 0.9392149448394775 seconds ---
# State confirmed as California
# 38 9 CA_SacramentoCounty.json
# --- 0.9399409294128418 seconds ---
# State confirmed as California
# 39 9 CA_SacramentoCounty.json
# --- 0.9428160190582275 seconds ---
# State confirmed as California
# 40 9 CA_SacramentoCounty.json
# --- 0.9665896892547607 seconds ---
# State confirmed as California
# 41 9 CA_SacramentoCounty.json
# --- 0.9501378536224365 seconds ---
# State confirmed as California
# 42 9 CA_SacramentoCounty.json
# --- 0.9452774524688721 seconds ---
# State confirmed as California
# 43 9 CA_SacramentoCounty.json
# --- 0.9463932514190674 seconds ---
# State confirmed as Florida
# 44 15 FL_ManateeCounty.json
# --- 0.7981853485107422 seconds ---
# State confirmed as Ohio
# 45 6 OH_CuyahogaCounty.json
# --- 0.5183093547821045 seconds ---
# State confirmed as California
# 46 9 CA_SacramentoCounty.json
# --- 0.9397733211517334 seconds ---
# State confirmed as California
# 47 9 CA_SacramentoCounty.json
# --- 0.9404311180114746 seconds ---
# State confirmed as Florida
# 48 15 FL_ManateeCounty.json
# --- 0.7978153228759766 seconds ---
# State confirmed as California
# 49 9 CA_SacramentoCounty.json
# --- 0.9400942325592041 seconds ---
# State confirmed as Ohio
# 50 6 OH_CuyahogaCounty.json
# --- 0.5171594619750977 seconds ---
# State confirmed as Ohio
# 51 6 OH_CuyahogaCounty.json
# --- 0.517240047454834 seconds ---
# State confirmed as Ohio
# 52 6 OH_CuyahogaCounty.json
# --- 0.5168361663818359 seconds ---
# State confirmed as Ohio
# 53 6 OH_CuyahogaCounty.json
# --- 0.5443291664123535 seconds ---
# State confirmed as Ohio
# 54 6 OH_CuyahogaCounty.json
# --- 0.5169467926025391 seconds ---
# State confirmed as Ohio
# 55 6 OH_CuyahogaCounty.json
# --- 0.5166308879852295 seconds ---
# State confirmed as Ohio
# 56 6 OH_CuyahogaCounty.json
# --- 0.5171992778778076 seconds ---
# State confirmed as Ohio
# 57 6 OH_CuyahogaCounty.json
# --- 0.5169005393981934 seconds ---
# State confirmed as Ohio
# 58 6 OH_CuyahogaCounty.json
# --- 0.5170512199401855 seconds ---
# State confirmed as Ohio
# 59 6 OH_CuyahogaCounty.json
# --- 0.5166888236999512 seconds ---
# State confirmed as Ohio
# 60 6 OH_CuyahogaCounty.json
# --- 0.5169315338134766 seconds ---
# State confirmed as Ohio
# 61 6 OH_CuyahogaCounty.json
# --- 0.5169551372528076 seconds ---
# State confirmed as Ohio
# 62 6 OH_CuyahogaCounty.json
# --- 0.5165121555328369 seconds ---
# State confirmed as Ohio
# 63 6 OH_CuyahogaCounty.json
# --- 0.5459408760070801 seconds ---
# State confirmed as Ohio
# 64 6 OH_CuyahogaCounty.json
# --- 0.5165913105010986 seconds ---
# State confirmed as Ohio
# 65 6 OH_CuyahogaCounty.json
# --- 0.5163137912750244 seconds ---
# State confirmed as Florida
# 66 34 FL_BrowardCounty.json
# --- 0.7703819274902344 seconds ---
# State confirmed as Florida
# 67 34 FL_BrowardCounty.json
# --- 0.7960968017578125 seconds ---
# State confirmed as Ohio
# 68 6 OH_CuyahogaCounty.json
# --- 0.517547607421875 seconds ---
# State confirmed as Ohio
# 69 6 OH_CuyahogaCounty.json
# --- 0.5165748596191406 seconds ---
# State confirmed as Florida
# 70 34 FL_BrowardCounty.json
# --- 0.7742743492126465 seconds ---
# State confirmed as Florida
# 71 34 FL_BrowardCounty.json
# --- 0.7980782985687256 seconds ---
# State confirmed as Ohio
# 72 6 OH_CuyahogaCounty.json
# --- 0.517225980758667 seconds ---
# State confirmed as Florida
# 73 34 FL_BrowardCounty.json
# --- 0.7705545425415039 seconds ---
# State confirmed as Florida
# 74 34 FL_BrowardCounty.json
# --- 0.7691702842712402 seconds ---
# State confirmed as Florida
# 75 34 FL_BrowardCounty.json
# --- 0.768791675567627 seconds ---
# State confirmed as Georgia
# 76 92 GA_BleckleyCounty.json
# --- 0.895057201385498 seconds ---
# State confirmed as Florida
# 77 34 FL_BrowardCounty.json
# --- 0.7715256214141846 seconds ---
# State confirmed as Georgia
# 78 92 GA_BleckleyCounty.json
# --- 0.8916783332824707 seconds ---
# State confirmed as Georgia
# 79 92 GA_BleckleyCounty.json
# --- 0.8899374008178711 seconds ---
# State confirmed as Georgia
# 80 92 GA_BleckleyCounty.json
# --- 0.889838695526123 seconds ---
# State confirmed as Georgia
# 81 92 GA_BleckleyCounty.json
# --- 0.8930814266204834 seconds ---
# State confirmed as Georgia
# 82 92 GA_BleckleyCounty.json
# --- 0.8642420768737793 seconds ---
# State confirmed as Florida
# 83 34 FL_BrowardCounty.json
# --- 0.7707574367523193 seconds ---
# State confirmed as Georgia
# 84 92 GA_BleckleyCounty.json
# --- 0.8643107414245605 seconds ---
# State confirmed as Georgia
# 85 92 GA_BleckleyCounty.json
# --- 0.8632402420043945 seconds ---
# State confirmed as Georgia
# 86 92 GA_BleckleyCounty.json
# --- 0.8952808380126953 seconds ---
# State confirmed as Georgia
# 87 92 GA_BleckleyCounty.json
# --- 0.8699371814727783 seconds ---
# State confirmed as Georgia
# 88 92 GA_BleckleyCounty.json
# --- 0.9027838706970215 seconds ---
# State confirmed as Georgia
# 89 92 GA_BleckleyCounty.json
# --- 0.9019784927368164 seconds ---
# State confirmed as Georgia
# 90 92 GA_BleckleyCounty.json
# --- 0.9002828598022461 seconds ---
# State confirmed as Georgia
# 91 92 GA_BleckleyCounty.json
# --- 0.9007906913757324 seconds ---
# State confirmed as Georgia
# 92 92 GA_BleckleyCounty.json
# --- 0.8995199203491211 seconds ---
# State confirmed as Georgia
# 93 92 GA_BleckleyCounty.json
# --- 0.9032082557678223 seconds ---
# State confirmed as Georgia
# 94 92 GA_BleckleyCounty.json
# --- 0.9007461071014404 seconds ---
# State confirmed as Georgia
# 95 92 GA_BleckleyCounty.json
# --- 0.8740057945251465 seconds ---
# State confirmed as Georgia
# 96 92 GA_BleckleyCounty.json
# --- 0.9025847911834717 seconds ---
# State confirmed as Nevada
# 97 3 NV_ClarkCounty.json
# --- 0.4944941997528076 seconds ---
# State confirmed as Nevada
# 98 3 NV_ClarkCounty.json
# --- 0.522270917892456 seconds ---
# State confirmed as Nevada
# 99 3 NV_ClarkCounty.json
# --- 0.4939234256744385 seconds ---
# State confirmed as Nevada
# 100 3 NV_ClarkCounty.json
# --- 0.4935774803161621 seconds ---
# State confirmed as Nevada
# 101 3 NV_ClarkCounty.json
# --- 0.49385547637939453 seconds ---
# State confirmed as Nevada
# 102 3 NV_ClarkCounty.json
# --- 0.5226151943206787 seconds ---
# State confirmed as Nevada
# 103 3 NV_ClarkCounty.json
# --- 0.493882417678833 seconds ---
# State confirmed as Nevada
# 104 3 NV_ClarkCounty.json
# --- 0.4993326663970947 seconds ---
# State confirmed as Nevada
# 105 3 NV_ClarkCounty.json
# --- 0.4987947940826416 seconds ---
# State confirmed as Nevada
# 106 3 NV_ClarkCounty.json
# --- 0.5289678573608398 seconds ---
# State confirmed as Nevada
# 107 3 NV_ClarkCounty.json
# --- 0.49892091751098633 seconds ---
# State confirmed as Nevada
# 108 3 NV_ClarkCounty.json
# --- 0.4990854263305664 seconds ---
# State confirmed as Nevada
# 109 3 NV_ClarkCounty.json
# --- 0.524500846862793 seconds ---
# State confirmed as Nevada
# 110 3 NV_ClarkCounty.json
# --- 0.49913620948791504 seconds ---
# State confirmed as Nevada
# 111 3 NV_ClarkCounty.json
# --- 0.49361252784729004 seconds ---
# State confirmed as Nevada
# 112 3 NV_ClarkCounty.json
# --- 0.49357175827026367 seconds ---
# State confirmed as Nevada
# 113 3 NV_ClarkCounty.json
# --- 0.5290529727935791 seconds ---
# State confirmed as Nevada
# 114 3 NV_ClarkCounty.json
# --- 0.4991631507873535 seconds ---
# State confirmed as Nevada
# 115 3 NV_ClarkCounty.json
# --- 0.4936227798461914 seconds ---
# State confirmed as Nevada
# 116 3 NV_ClarkCounty.json
# --- 0.4940497875213623 seconds ---
# State confirmed as Arizona
# 117 1 AZ_MaricopaCounty.json
# --- 0.5472822189331055 seconds ---
# State confirmed as Nevada
# 118 3 NV_ClarkCounty.json
# --- 0.4941575527191162 seconds ---
# State confirmed as Arizona
# 119 11 AZ_PimaCounty.json
# --- 0.54606032371521 seconds ---
# State confirmed as Arizona
# 120 11 AZ_PimaCounty.json
# --- 0.5436384677886963 seconds ---
# State confirmed as Arizona
# 121 11 AZ_PimaCounty.json
# --- 0.5157852172851562 seconds ---
# State confirmed as Nevada
# 122 3 NV_ClarkCounty.json
# --- 0.4938333034515381 seconds ---
# State confirmed as Nevada
# 123 3 NV_ClarkCounty.json
# --- 0.5228300094604492 seconds ---
# State confirmed as Arizona
# 124 11 AZ_PimaCounty.json
# --- 0.5160317420959473 seconds ---
# State confirmed as Nevada
# 125 3 NV_ClarkCounty.json
# --- 0.5221412181854248 seconds ---
# State confirmed as Arizona
# 126 11 AZ_PimaCounty.json
# --- 0.5151593685150146 seconds ---
# State confirmed as Nevada
# 127 3 NV_ClarkCounty.json
# --- 0.493945837020874 seconds ---
# State confirmed as Arizona
# 128 11 AZ_PimaCounty.json
# --- 0.5446152687072754 seconds ---
# State confirmed as Arizona
# 129 11 AZ_PimaCounty.json
# --- 0.5436728000640869 seconds ---
# State confirmed as Arizona
# 130 11 AZ_PimaCounty.json
# --- 0.5149970054626465 seconds ---
# State confirmed as Arizona
# 131 11 AZ_PimaCounty.json
# --- 0.5431995391845703 seconds ---
# State confirmed as Arizona
# 132 11 AZ_PimaCounty.json
# --- 0.5447268486022949 seconds ---
# State confirmed as Arizona
# 133 11 AZ_PimaCounty.json
# --- 0.5154359340667725 seconds ---
# State confirmed as Arizona
# 134 11 AZ_PimaCounty.json
# --- 0.544579029083252 seconds ---
# State confirmed as Arizona
# 135 11 AZ_PimaCounty.json
# --- 0.5171868801116943 seconds ---
# State confirmed as Arizona
# 136 11 AZ_PimaCounty.json
# --- 0.5465033054351807 seconds ---
# State confirmed as Arizona
# 137 11 AZ_PimaCounty.json
# --- 0.5444967746734619 seconds ---
# State confirmed as Oklahoma
# 138 34 OK_OsageCounty.json
# --- 0.49884819984436035 seconds ---
# State confirmed as Oklahoma
# 139 34 OK_OsageCounty.json
# --- 0.4978160858154297 seconds ---
# State confirmed as Oklahoma
# 140 34 OK_OsageCounty.json
# --- 0.497081995010376 seconds ---
# State confirmed as Oklahoma
# 141 52 OK_TulsaCounty.json
# --- 0.4961690902709961 seconds ---
# State confirmed as Oklahoma
# 142 52 OK_TulsaCounty.json
# --- 0.4963033199310303 seconds ---
# State confirmed as Oklahoma
# 143 52 OK_TulsaCounty.json
# --- 0.496319055557251 seconds ---
# State confirmed as Oklahoma
# 144 52 OK_TulsaCounty.json
# --- 0.49651336669921875 seconds ---
# State confirmed as Oklahoma
# 145 52 OK_TulsaCounty.json
# --- 0.4962460994720459 seconds ---
# State confirmed as Oklahoma
# 146 52 OK_TulsaCounty.json
# --- 0.49655985832214355 seconds ---
# State confirmed as Oklahoma
# 147 52 OK_TulsaCounty.json
# --- 0.4970090389251709 seconds ---
# State confirmed as Oklahoma
# 148 52 OK_TulsaCounty.json
# --- 0.49649810791015625 seconds ---
# State confirmed as Oklahoma
# 149 52 OK_TulsaCounty.json
# --- 0.49648189544677734 seconds ---
# State confirmed as Oklahoma
# 150 34 OK_OsageCounty.json
# --- 0.49724483489990234 seconds ---
# State confirmed as Oklahoma
# 151 34 OK_OsageCounty.json
# --- 0.49713993072509766 seconds ---
# State confirmed as Oklahoma
# 152 52 OK_TulsaCounty.json
# --- 0.4965982437133789 seconds ---
# State confirmed as Oklahoma
# 153 34 OK_OsageCounty.json
# --- 0.4972388744354248 seconds ---
# State confirmed as Oklahoma
# 154 34 OK_OsageCounty.json
# --- 0.4973139762878418 seconds ---
# State confirmed as Oklahoma
# 155 52 OK_TulsaCounty.json
# --- 0.49710750579833984 seconds ---
# State confirmed as Oklahoma
# 156 52 OK_TulsaCounty.json
# --- 0.4964728355407715 seconds ---
# State confirmed as NorthCarolina
# 157 77 NC_DuplinCounty.json
# --- 0.6193978786468506 seconds ---
# State confirmed as NorthCarolina
# 158 77 NC_DuplinCounty.json
# --- 0.6155586242675781 seconds ---
# State confirmed as NorthCarolina
# 159 77 NC_DuplinCounty.json
# --- 0.6142191886901855 seconds ---
# State confirmed as NorthCarolina
# 160 77 NC_DuplinCounty.json
# --- 0.6146528720855713 seconds ---
# State confirmed as Oklahoma
# 161 52 OK_TulsaCounty.json
# --- 0.4968552589416504 seconds ---
# State confirmed as NorthCarolina
# 162 77 NC_DuplinCounty.json
# --- 0.614647626876831 seconds ---
# State confirmed as NorthCarolina
# 163 77 NC_DuplinCounty.json
# --- 0.614938497543335 seconds ---
# State confirmed as NorthCarolina
# 164 77 NC_DuplinCounty.json
# --- 0.6133646965026855 seconds ---
# State confirmed as NorthCarolina
# 165 77 NC_DuplinCounty.json
# --- 0.6139142513275146 seconds ---
# State confirmed as California
# 166 34 CA_TulareCounty.json
# --- 0.9830987453460693 seconds ---
# State confirmed as NorthCarolina
# 167 77 NC_DuplinCounty.json
# --- 0.6138942241668701 seconds ---
# State confirmed as California
# 168 34 CA_TulareCounty.json
# --- 0.9761900901794434 seconds ---
# State confirmed as NorthCarolina
# 169 77 NC_DuplinCounty.json
# --- 0.6165831089019775 seconds ---
# State confirmed as NorthCarolina
# 170 77 NC_DuplinCounty.json
# --- 0.6158866882324219 seconds ---
# State confirmed as NorthCarolina
# 171 77 NC_DuplinCounty.json
# --- 0.6173572540283203 seconds ---
# State confirmed as NorthCarolina
# 172 77 NC_DuplinCounty.json
# --- 0.5865180492401123 seconds ---
# State confirmed as NorthCarolina
# 173 77 NC_DuplinCounty.json
# --- 0.6187708377838135 seconds ---
# State confirmed as Oklahoma
# 174 52 OK_TulsaCounty.json
# --- 0.4964151382446289 seconds ---
# State confirmed as NorthCarolina
# 175 20 NC_LenoirCounty.json
# --- 0.6154084205627441 seconds ---
# State confirmed as NorthCarolina
# 176 20 NC_LenoirCounty.json
# --- 0.6165356636047363 seconds ---
# State confirmed as NorthCarolina
# 177 5 NC_PittCounty.json
# --- 0.617079496383667 seconds ---
# State confirmed as NorthCarolina
# 178 5 NC_PittCounty.json
# --- 0.616553544998169 seconds ---
# State confirmed as NorthCarolina
# 179 5 NC_PittCounty.json
# --- 0.6155862808227539 seconds ---
# State confirmed as NorthCarolina
# 180 20 NC_LenoirCounty.json
# --- 0.6137728691101074 seconds ---
# State confirmed as NorthCarolina
# 181 20 NC_LenoirCounty.json
# --- 0.613793134689331 seconds ---
# State confirmed as NorthCarolina
# 182 20 NC_LenoirCounty.json
# --- 0.6132693290710449 seconds ---
# State confirmed as NorthCarolina
# 183 28 NC_BeaufortCounty.json
# --- 0.6167974472045898 seconds ---
# State confirmed as NorthCarolina
# 184 28 NC_BeaufortCounty.json
# --- 0.615602970123291 seconds ---
# State confirmed as NorthCarolina
# 185 28 NC_BeaufortCounty.json
# --- 0.58831787109375 seconds ---
# State confirmed as NorthCarolina
# 186 28 NC_BeaufortCounty.json
# --- 0.6162500381469727 seconds ---
# State confirmed as NorthCarolina
# 187 28 NC_BeaufortCounty.json
# --- 0.6227920055389404 seconds ---
# State confirmed as NorthCarolina
# 188 28 NC_BeaufortCounty.json
# --- 0.620112419128418 seconds ---
# State confirmed as NorthCarolina
# 189 28 NC_BeaufortCounty.json
# --- 0.6162629127502441 seconds ---
# State confirmed as NorthCarolina
# 190 28 NC_BeaufortCounty.json
# --- 0.6169695854187012 seconds ---
# State confirmed as NorthCarolina
# 191 28 NC_BeaufortCounty.json
# --- 0.6168460845947266 seconds ---
# State confirmed as NorthCarolina
# 192 5 NC_PittCounty.json
# --- 0.6161391735076904 seconds ---
# State confirmed as NorthCarolina
# 193 5 NC_PittCounty.json
# --- 0.615797758102417 seconds ---
# State confirmed as NorthCarolina
# 194 5 NC_PittCounty.json
# --- 0.6158914566040039 seconds ---
# State confirmed as NorthCarolina
# 195 5 NC_PittCounty.json
# --- 0.6158978939056396 seconds ---
# State confirmed as NorthCarolina
# 196 5 NC_PittCounty.json
# --- 0.6150140762329102 seconds ---
# State confirmed as NorthCarolina
# 197 28 NC_BeaufortCounty.json
# --- 0.6157510280609131 seconds ---
# State confirmed as NorthCarolina
# 198 5 NC_PittCounty.json
# --- 0.6153578758239746 seconds ---
# State confirmed as NorthCarolina
# 199 20 NC_LenoirCounty.json
# --- 0.6145493984222412 seconds ---
# State confirmed as NorthCarolina
# 200 28 NC_BeaufortCounty.json
# --- 0.6168708801269531 seconds ---
# State confirmed as NorthCarolina
# 201 20 NC_LenoirCounty.json
# --- 0.612440824508667 seconds ---
# State confirmed as NorthCarolina
# 202 20 NC_LenoirCounty.json
# --- 0.6142361164093018 seconds ---
# State confirmed as NorthCarolina
# 203 20 NC_LenoirCounty.json
# --- 0.614086389541626 seconds ---
# State confirmed as NorthCarolina
# 204 20 NC_LenoirCounty.json
# --- 0.6141879558563232 seconds ---
# State confirmed as NorthCarolina
# 205 20 NC_LenoirCounty.json
# --- 0.5853006839752197 seconds ---
# State confirmed as NorthCarolina
# 206 20 NC_LenoirCounty.json
# --- 0.6145894527435303 seconds ---
# State confirmed as NorthCarolina
# 207 20 NC_LenoirCounty.json
# --- 0.6129167079925537 seconds ---
# State confirmed as NorthCarolina
# 208 20 NC_LenoirCounty.json
# --- 0.6138143539428711 seconds ---
# State confirmed as NorthCarolina
# 209 20 NC_LenoirCounty.json
# --- 0.5841028690338135 seconds ---
# State confirmed as NorthCarolina
# 210 20 NC_LenoirCounty.json
# --- 0.6147356033325195 seconds ---
# State confirmed as NorthCarolina
# 211 77 NC_DuplinCounty.json
# --- 0.6154208183288574 seconds ---
# State confirmed as NorthCarolina
# 212 77 NC_DuplinCounty.json
# --- 0.6144249439239502 seconds ---
# State confirmed as NorthCarolina
# 213 77 NC_DuplinCounty.json
# --- 0.6145946979522705 seconds ---
# State confirmed as NorthCarolina
# 214 77 NC_DuplinCounty.json
# --- 0.6142854690551758 seconds ---
# State confirmed as NorthCarolina
# 215 77 NC_DuplinCounty.json
# --- 0.614417552947998 seconds ---
# State confirmed as NorthCarolina
# 216 77 NC_DuplinCounty.json
# --- 0.585071325302124 seconds ---
# State confirmed as NorthCarolina
# 217 77 NC_DuplinCounty.json
# --- 0.6144237518310547 seconds ---
# State confirmed as NorthCarolina
# 218 77 NC_DuplinCounty.json
# --- 0.6159021854400635 seconds ---
# State confirmed as NorthCarolina
# 219 77 NC_DuplinCounty.json
# --- 0.6139695644378662 seconds ---
# State confirmed as NorthCarolina
# 220 20 NC_LenoirCounty.json
# --- 0.6134946346282959 seconds ---
# State confirmed as NorthCarolina
# 221 77 NC_DuplinCounty.json
# --- 0.6140756607055664 seconds ---
# State confirmed as NorthCarolina
# 222 20 NC_LenoirCounty.json
# --- 0.6137769222259521 seconds ---
# State confirmed as NorthCarolina
# 223 77 NC_DuplinCounty.json
# --- 0.6147751808166504 seconds ---
# State confirmed as NorthCarolina
# 224 77 NC_DuplinCounty.json
# --- 0.6133472919464111 seconds ---
# State confirmed as NorthCarolina
# 225 77 NC_DuplinCounty.json
# --- 0.6158139705657959 seconds ---
# State confirmed as NorthCarolina
# 226 77 NC_DuplinCounty.json
# --- 0.6191661357879639 seconds ---
# State confirmed as NorthCarolina
# 227 77 NC_DuplinCounty.json
# --- 0.6180036067962646 seconds ---
# State confirmed as NorthCarolina
# 228 77 NC_DuplinCounty.json
# --- 0.5858502388000488 seconds ---
# State confirmed as Florida
# 229 34 FL_BrowardCounty.json
# --- 0.8264956474304199 seconds ---
# State confirmed as Florida
# 230 34 FL_BrowardCounty.json
# --- 0.7990336418151855 seconds ---
# State confirmed as Florida
# 231 34 FL_BrowardCounty.json
# --- 0.777545690536499 seconds ---
# State confirmed as Texas
# 232 107 TX_HarrisCounty.json
# --- 0.7399098873138428 seconds ---
# State confirmed as Texas
# 233 107 TX_HarrisCounty.json
# --- 0.7011106014251709 seconds ---
# State confirmed as Texas
# 234 107 TX_HarrisCounty.json
# --- 0.7482624053955078 seconds ---
# State confirmed as Texas
# 235 107 TX_HarrisCounty.json
# --- 0.744753360748291 seconds ---
# State confirmed as Florida
# 236 44 FL_PalmBeachCounty.json
# --- 0.7994835376739502 seconds ---
# State confirmed as Florida
# 237 44 FL_PalmBeachCounty.json
# --- 0.8341748714447021 seconds ---
# State confirmed as Florida
# 238 34 FL_BrowardCounty.json
# --- 0.7922987937927246 seconds ---
# State confirmed as Florida
# 239 44 FL_PalmBeachCounty.json
# --- 0.7990319728851318 seconds ---
# State confirmed as Florida
# 240 44 FL_PalmBeachCounty.json
# --- 0.7987139225006104 seconds ---
# State confirmed as Florida
# 241 44 FL_PalmBeachCounty.json
# --- 0.8164107799530029 seconds ---
# State confirmed as Florida
# 242 44 FL_PalmBeachCounty.json
# --- 0.7900614738464355 seconds ---
# State confirmed as Florida
# 243 44 FL_PalmBeachCounty.json
# --- 0.7912449836730957 seconds ---
# State confirmed as Florida
# 244 44 FL_PalmBeachCounty.json
# --- 0.7924447059631348 seconds ---
# State confirmed as Florida
# 245 44 FL_PalmBeachCounty.json
# --- 0.7825405597686768 seconds ---
# State confirmed as Florida
# 246 44 FL_PalmBeachCounty.json
# --- 0.8302268981933594 seconds ---
# State confirmed as Florida
# 247 44 FL_PalmBeachCounty.json
# --- 0.7942090034484863 seconds ---
# State confirmed as Florida
# 248 34 FL_BrowardCounty.json
# --- 0.7843306064605713 seconds ---
# State confirmed as Florida
# 249 44 FL_PalmBeachCounty.json
# --- 0.7951469421386719 seconds ---
# State confirmed as Florida
# 250 34 FL_BrowardCounty.json
# --- 0.8209338188171387 seconds ---
# State confirmed as Florida
# 251 44 FL_PalmBeachCounty.json
# --- 0.7909390926361084 seconds ---
# State confirmed as Florida
# 252 44 FL_PalmBeachCounty.json
# --- 0.7947313785552979 seconds ---
# State confirmed as Florida
# 253 44 FL_PalmBeachCounty.json
# --- 0.7822785377502441 seconds ---
# State confirmed as California
# 254 25 CA_SantaCruzCounty.json
# --- 0.9726002216339111 seconds ---
# State confirmed as California
# 255 25 CA_SantaCruzCounty.json
# --- 1.0035889148712158 seconds ---
# State confirmed as California
# 256 25 CA_SantaCruzCounty.json
# --- 0.9696121215820312 seconds ---
# State confirmed as California
# 257 25 CA_SantaCruzCounty.json
# --- 0.9566256999969482 seconds ---
# State confirmed as California
# 258 25 CA_SantaCruzCounty.json
# --- 0.9663426876068115 seconds ---
# State confirmed as California
# 259 25 CA_SantaCruzCounty.json
# --- 1.0039293766021729 seconds ---
# State confirmed as California
# 260 33 CA_SanMateoCounty.json
# --- 0.9399244785308838 seconds ---
# State confirmed as California
# 261 33 CA_SanMateoCounty.json
# --- 0.9505453109741211 seconds ---
# State confirmed as California
# 262 33 CA_SanMateoCounty.json
# --- 0.9619011878967285 seconds ---
# State confirmed as California
# 263 33 CA_SanMateoCounty.json
# --- 0.9685335159301758 seconds ---
# State confirmed as California
# 264 25 CA_SantaCruzCounty.json
# --- 0.9410145282745361 seconds ---
# State confirmed as California
# 265 25 CA_SantaCruzCounty.json
# --- 0.939723014831543 seconds ---
# State confirmed as California
# 266 33 CA_SanMateoCounty.json
# --- 0.9346070289611816 seconds ---
# State confirmed as California
# 267 33 CA_SanMateoCounty.json
# --- 0.9543259143829346 seconds ---
# State confirmed as California
# 268 33 CA_SanMateoCounty.json
# --- 0.9642171859741211 seconds ---
# State confirmed as California
# 269 33 CA_SanMateoCounty.json
# --- 0.9355571269989014 seconds ---
# State confirmed as California
# 270 33 CA_SanMateoCounty.json
# --- 0.9364933967590332 seconds ---
# State confirmed as California
# 271 33 CA_SanMateoCounty.json
# --- 0.9362919330596924 seconds ---
# State confirmed as California
# 272 33 CA_SanMateoCounty.json
# --- 0.9374046325683594 seconds ---
# State confirmed as California
# 273 33 CA_SanMateoCounty.json
# --- 0.965949296951294 seconds ---
# State confirmed as California
# 274 25 CA_SantaCruzCounty.json
# --- 0.9376091957092285 seconds ---
# State confirmed as California
# 275 33 CA_SanMateoCounty.json
# --- 0.9473013877868652 seconds ---
# State confirmed as California
# 276 33 CA_SanMateoCounty.json
# --- 0.9358415603637695 seconds ---
# State confirmed as California
# 277 25 CA_SantaCruzCounty.json
# --- 0.9652910232543945 seconds ---
# State confirmed as California
# 278 25 CA_SantaCruzCounty.json
# --- 0.9358861446380615 seconds ---
# State confirmed as California
# 279 33 CA_SanMateoCounty.json
# --- 0.9357678890228271 seconds ---
# State confirmed as California
# 280 25 CA_SantaCruzCounty.json
# --- 0.9351375102996826 seconds ---
# State confirmed as California
# 281 25 CA_SantaCruzCounty.json
# --- 0.9639167785644531 seconds ---
# State confirmed as California
# 282 25 CA_SantaCruzCounty.json
# --- 0.9477622509002686 seconds ---
# State confirmed as California
# 283 25 CA_SantaCruzCounty.json
# --- 0.9439125061035156 seconds ---
# State confirmed as California
# 284 25 CA_SantaCruzCounty.json
# --- 0.9452652931213379 seconds ---
# State confirmed as California
# 285 25 CA_SantaCruzCounty.json
# --- 0.9426641464233398 seconds ---
# State confirmed as California
# 286 25 CA_SantaCruzCounty.json
# --- 0.9668292999267578 seconds ---
# State confirmed as California
# 287 25 CA_SantaCruzCounty.json
# --- 0.9386889934539795 seconds ---
# State confirmed as California
# 288 25 CA_SantaCruzCounty.json
# --- 0.9363491535186768 seconds ---
# State confirmed as California
# 289 25 CA_SantaCruzCounty.json
# --- 0.9371421337127686 seconds ---
# State confirmed as California
# 290 25 CA_SantaCruzCounty.json
# --- 0.9633591175079346 seconds ---
# State confirmed as California
# 291 25 CA_SantaCruzCounty.json
# --- 0.9460036754608154 seconds ---
# State confirmed as California
# 292 25 CA_SantaCruzCounty.json
# --- 0.9375669956207275 seconds ---
# State confirmed as California
# 293 25 CA_SantaCruzCounty.json
# --- 0.9358205795288086 seconds ---
# State confirmed as California
# 294 42 CA_SantaClaraCounty.json
# --- 0.9731540679931641 seconds ---
# State confirmed as California
# 295 42 CA_SantaClaraCounty.json
# --- 0.9468910694122314 seconds ---
# State confirmed as California
# 296 42 CA_SantaClaraCounty.json
# --- 0.9412775039672852 seconds ---
# State confirmed as California
# 297 42 CA_SantaClaraCounty.json
# --- 0.9715092182159424 seconds ---
# State confirmed as California
# 298 42 CA_SantaClaraCounty.json
# --- 0.9446163177490234 seconds ---
# State confirmed as California
# 299 42 CA_SantaClaraCounty.json
# --- 0.951798677444458 seconds ---
# State confirmed as California
# 300 33 CA_SanMateoCounty.json
# --- 0.9363918304443359 seconds ---
# State confirmed as California
# 301 33 CA_SanMateoCounty.json
# --- 0.965778112411499 seconds ---
# State confirmed as California
# 302 33 CA_SanMateoCounty.json
# --- 0.9368891716003418 seconds ---
# State confirmed as California
# 303 33 CA_SanMateoCounty.json
# --- 0.9353363513946533 seconds ---
# State confirmed as California
# 304 42 CA_SantaClaraCounty.json
# --- 0.9559111595153809 seconds ---
# State confirmed as California
# 305 33 CA_SanMateoCounty.json
# --- 0.9690649509429932 seconds ---
# State confirmed as California
# 306 33 CA_SanMateoCounty.json
# --- 0.93611741065979 seconds ---
# State confirmed as California
# 307 42 CA_SantaClaraCounty.json
# --- 0.9462978839874268 seconds ---
# State confirmed as California
# 308 33 CA_SanMateoCounty.json
# --- 0.9349856376647949 seconds ---
# State confirmed as California
# 309 33 CA_SanMateoCounty.json
# --- 0.9640634059906006 seconds ---
# State confirmed as California
# 310 31 CA_ImperialCounty.json
# --- 1.1883916854858398 seconds ---
# State confirmed as California
# 311 31 CA_ImperialCounty.json
# --- 1.220574140548706 seconds ---
# State confirmed as California
# 312 31 CA_ImperialCounty.json
# --- 1.189863681793213 seconds ---
# State confirmed as California
# 313 33 CA_SanMateoCounty.json
# --- 0.9609026908874512 seconds ---
# State confirmed as California
# 314 31 CA_ImperialCounty.json
# --- 1.1884479522705078 seconds ---
# State confirmed as California
# 315 31 CA_ImperialCounty.json
# --- 1.2160656452178955 seconds ---
# State confirmed as California
# 316 31 CA_ImperialCounty.json
# --- 1.2098050117492676 seconds ---
# State confirmed as California
# 317 31 CA_ImperialCounty.json
# --- 1.1889889240264893 seconds ---
# State confirmed as California
# 318 31 CA_ImperialCounty.json
# --- 1.2101702690124512 seconds ---
# State confirmed as California
# 319 31 CA_ImperialCounty.json
# --- 1.1930439472198486 seconds ---
# State confirmed as California
# 320 31 CA_ImperialCounty.json
# --- 1.219602108001709 seconds ---
# State confirmed as Illinois
# 321 81 IL_CookCounty.json
# --- 0.5031850337982178 seconds ---
# State confirmed as Illinois
# 322 81 IL_CookCounty.json
# --- 0.5026507377624512 seconds ---
# State confirmed as Illinois
# 323 81 IL_CookCounty.json
# --- 0.5023763179779053 seconds ---
# State confirmed as Illinois
# 324 81 IL_CookCounty.json
# --- 0.5292661190032959 seconds ---
# State confirmed as Illinois
# 325 81 IL_CookCounty.json
# --- 0.5027029514312744 seconds ---
# State confirmed as Illinois
# 326 81 IL_CookCounty.json
# --- 0.5033426284790039 seconds ---
# State confirmed as Illinois
# 327 81 IL_CookCounty.json
# --- 0.5027492046356201 seconds ---
# State confirmed as Illinois
# 328 81 IL_CookCounty.json
# --- 0.5029690265655518 seconds ---
# State confirmed as Illinois
# 329 81 IL_CookCounty.json
# --- 0.5026912689208984 seconds ---
# State confirmed as Illinois
# 330 81 IL_CookCounty.json
# --- 0.5030407905578613 seconds ---
# State confirmed as Illinois
# 331 81 IL_CookCounty.json
# --- 0.5028054714202881 seconds ---
# State confirmed as Illinois
# 332 81 IL_CookCounty.json
# --- 0.5029270648956299 seconds ---
# State confirmed as Illinois
# 333 81 IL_CookCounty.json
# --- 0.5028247833251953 seconds ---
# State confirmed as Illinois
# 334 81 IL_CookCounty.json
# --- 0.5026381015777588 seconds ---
# State confirmed as Illinois
# 335 81 IL_CookCounty.json
# --- 0.5294008255004883 seconds ---
# State confirmed as Illinois
# 336 81 IL_CookCounty.json
# --- 0.5024595260620117 seconds ---
# State confirmed as Illinois
# 337 81 IL_CookCounty.json
# --- 0.5034995079040527 seconds ---
# State confirmed as Illinois
# 338 81 IL_CookCounty.json
# --- 0.5023148059844971 seconds ---
# State confirmed as Illinois
# 339 81 IL_CookCounty.json
# --- 0.5029947757720947 seconds ---
# State confirmed as Illinois
# 340 81 IL_CookCounty.json
# --- 0.5030615329742432 seconds ---
# State confirmed as Illinois
# 341 81 IL_CookCounty.json
# --- 0.5027098655700684 seconds ---
# State confirmed as Illinois
# 342 81 IL_CookCounty.json
# --- 0.5026705265045166 seconds ---
# State confirmed as Illinois
# 343 81 IL_CookCounty.json
# --- 0.5032134056091309 seconds ---
# State confirmed as Illinois
# 344 81 IL_CookCounty.json
# --- 0.5028011798858643 seconds ---
# State confirmed as Illinois
# 345 81 IL_CookCounty.json
# --- 0.5302865505218506 seconds ---
# State confirmed as Illinois
# 346 81 IL_CookCounty.json
# --- 0.5027563571929932 seconds ---
# State confirmed as Georgia
# 347 55 GA_ColumbiaCounty.json
# --- 0.8705008029937744 seconds ---
# State confirmed as Washington
# 348 7 WA_WhatcomCounty.json
# --- 0.5211553573608398 seconds ---
# State confirmed as Washington
# 349 7 WA_WhatcomCounty.json
# --- 0.5463376045227051 seconds ---
# State confirmed as California
# 350 9 CA_SacramentoCounty.json
# --- 0.9387557506561279 seconds ---
# State confirmed as Georgia
# 351 55 GA_ColumbiaCounty.json
# --- 0.8987216949462891 seconds ---
# State confirmed as Georgia
# 352 55 GA_ColumbiaCounty.json
# --- 0.8970668315887451 seconds ---
# State confirmed as California
# 353 9 CA_SacramentoCounty.json
# --- 0.9324944019317627 seconds ---
# State confirmed as Georgia
# 354 32 GA_RichmondCounty.json
# --- 0.895315408706665 seconds ---
# State confirmed as Georgia
# 355 55 GA_ColumbiaCounty.json
# --- 0.8681542873382568 seconds ---
# State confirmed as Georgia
# 356 55 GA_ColumbiaCounty.json
# --- 0.8959388732910156 seconds ---
# State confirmed as Georgia
# 357 32 GA_RichmondCounty.json
# --- 0.8667411804199219 seconds ---
# State confirmed as Georgia
# 358 32 GA_RichmondCounty.json
# --- 0.8926246166229248 seconds ---
# State confirmed as Georgia
# 359 55 GA_ColumbiaCounty.json
# --- 0.867790699005127 seconds ---
# State confirmed as Pennsylvania
# 360 46 PA_ErieCounty.json
# --- 0.6417338848114014 seconds ---
# State confirmed as Pennsylvania
# 361 46 PA_ErieCounty.json
# --- 0.6416049003601074 seconds ---
# State confirmed as Pennsylvania
# 362 46 PA_ErieCounty.json
# --- 0.6400489807128906 seconds ---
# State confirmed as Pennsylvania
# 363 46 PA_ErieCounty.json
# --- 0.6413552761077881 seconds ---
# State confirmed as Pennsylvania
# 364 46 PA_ErieCounty.json
# --- 0.6400880813598633 seconds ---
# State confirmed as Pennsylvania
# 365 46 PA_ErieCounty.json
# --- 0.6411406993865967 seconds ---
# State confirmed as Pennsylvania
# 366 46 PA_ErieCounty.json
# --- 0.6408789157867432 seconds ---
# State confirmed as Maryland
# 367 8 MD_GarrettCounty.json
# --- 0.759406566619873 seconds ---
# State confirmed as Pennsylvania
# 368 46 PA_ErieCounty.json
# --- 0.6404070854187012 seconds ---
# State confirmed as Illinois
# 369 68 IL_WilliamsonCounty.json
# --- 0.49945545196533203 seconds ---
# State confirmed as Illinois
# 370 68 IL_WilliamsonCounty.json
# --- 0.49904847145080566 seconds ---
# State confirmed as Pennsylvania
# 371 46 PA_ErieCounty.json
# --- 0.6419053077697754 seconds ---
# State confirmed as Illinois
# 372 68 IL_WilliamsonCounty.json
# --- 0.49901723861694336 seconds ---
# State confirmed as Illinois
# 373 68 IL_WilliamsonCounty.json
# --- 0.49881720542907715 seconds ---
# State confirmed as Pennsylvania
# 374 46 PA_ErieCounty.json
# --- 0.6421332359313965 seconds ---
# State confirmed as Illinois
# 375 68 IL_WilliamsonCounty.json
# --- 0.49880075454711914 seconds ---
# State confirmed as Illinois
# 376 68 IL_WilliamsonCounty.json
# --- 0.4986915588378906 seconds ---
# State confirmed as Illinois
# 377 68 IL_WilliamsonCounty.json
# --- 0.49869418144226074 seconds ---
# State confirmed as Illinois
# 378 68 IL_WilliamsonCounty.json
# --- 0.49863743782043457 seconds ---
# State confirmed as Illinois
# 379 68 IL_WilliamsonCounty.json
# --- 0.49918484687805176 seconds ---
# State confirmed as Illinois
# 380 68 IL_WilliamsonCounty.json
# --- 0.49899888038635254 seconds ---
# State confirmed as Illinois
# 381 68 IL_WilliamsonCounty.json
# --- 0.49924349784851074 seconds ---
# State confirmed as Illinois
# 382 68 IL_WilliamsonCounty.json
# --- 0.49889492988586426 seconds ---
# State confirmed as Illinois
# 383 68 IL_WilliamsonCounty.json
# --- 0.49852800369262695 seconds ---
# State confirmed as Illinois
# 384 68 IL_WilliamsonCounty.json
# --- 0.5257813930511475 seconds ---
# State confirmed as Illinois
# 385 68 IL_WilliamsonCounty.json
# --- 0.4988222122192383 seconds ---
# State confirmed as Illinois
# 386 68 IL_WilliamsonCounty.json
# --- 0.4986593723297119 seconds ---
# State confirmed as Illinois
# 387 31 IL_JohnsonCounty.json
# --- 0.5000982284545898 seconds ---
# State confirmed as Illinois
# 388 31 IL_JohnsonCounty.json
# --- 0.4988250732421875 seconds ---
# State confirmed as Illinois
# 389 68 IL_WilliamsonCounty.json
# --- 0.49875903129577637 seconds ---
# State confirmed as Illinois
# 390 68 IL_WilliamsonCounty.json
# --- 0.4987649917602539 seconds ---
# State confirmed as Illinois
# 391 68 IL_WilliamsonCounty.json
# --- 0.4990119934082031 seconds ---
# State confirmed as Illinois
# 392 68 IL_WilliamsonCounty.json
# --- 0.4987049102783203 seconds ---
# State confirmed as Illinois
# 393 68 IL_WilliamsonCounty.json
# --- 0.4988112449645996 seconds ---
# State confirmed as Illinois
# 394 54 IL_UnionCounty.json
# --- 0.49951696395874023 seconds ---
# State confirmed as Illinois
# 395 68 IL_WilliamsonCounty.json
# --- 0.49916505813598633 seconds ---
# State confirmed as Illinois
# 396 76 IL_JacksonCounty.json
# --- 0.49915456771850586 seconds ---
# State confirmed as Illinois
# 397 76 IL_JacksonCounty.json
# --- 0.499114990234375 seconds ---
# State confirmed as Illinois
# 398 76 IL_JacksonCounty.json
# --- 0.499478816986084 seconds ---
# State confirmed as Illinois
# 399 76 IL_JacksonCounty.json
# --- 0.499403715133667 seconds ---
# State confirmed as NorthCarolina
# 400 88 NC_ChathamCounty.json
# --- 0.6121764183044434 seconds ---
# State confirmed as NorthCarolina
# 401 79 NC_WakeCounty.json
# --- 0.6127738952636719 seconds ---
# State confirmed as NorthCarolina
# 402 22 NC_LeeCounty.json
# --- 0.6087081432342529 seconds ---
# State confirmed as NorthCarolina
# 403 22 NC_LeeCounty.json
# --- 0.6088380813598633 seconds ---
# State confirmed as NorthCarolina
# 404 88 NC_ChathamCounty.json
# --- 0.6088540554046631 seconds ---
# State confirmed as NorthCarolina
# 405 22 NC_LeeCounty.json
# --- 0.6146082878112793 seconds ---
# State confirmed as NorthCarolina
# 406 79 NC_WakeCounty.json
# --- 0.5832548141479492 seconds ---
# State confirmed as NorthCarolina
# 407 79 NC_WakeCounty.json
# --- 0.6130926609039307 seconds ---
# State confirmed as NorthCarolina
# 408 88 NC_ChathamCounty.json
# --- 0.6129138469696045 seconds ---
# State confirmed as NorthCarolina
# 409 88 NC_ChathamCounty.json
# --- 0.6100211143493652 seconds ---
# State confirmed as NorthCarolina
# 410 22 NC_LeeCounty.json
# --- 0.6086111068725586 seconds ---
# State confirmed as Florida
# 411 20 FL_LeeCounty.json
# --- 0.7926788330078125 seconds ---
# State confirmed as NorthCarolina
# 412 79 NC_WakeCounty.json
# --- 0.5836591720581055 seconds ---
# State confirmed as NorthCarolina
# 413 79 NC_WakeCounty.json
# --- 0.6101484298706055 seconds ---
# State confirmed as Florida
# 414 20 FL_LeeCounty.json
# --- 0.7939848899841309 seconds ---
# State confirmed as Florida
# 415 20 FL_LeeCounty.json
# --- 0.765338659286499 seconds ---
# State confirmed as Florida
# 416 20 FL_LeeCounty.json
# --- 0.7650692462921143 seconds ---
# State confirmed as Florida
# 417 20 FL_LeeCounty.json
# --- 0.7649271488189697 seconds ---
# State confirmed as Florida
# 418 20 FL_LeeCounty.json
# --- 0.7649993896484375 seconds ---
# State confirmed as Florida
# 419 26 FL_CharlotteCounty.json
# --- 0.7920653820037842 seconds ---
# State confirmed as Florida
# 420 26 FL_CharlotteCounty.json
# --- 0.767406702041626 seconds ---
# State confirmed as Florida
# 421 26 FL_CharlotteCounty.json
# --- 0.7647194862365723 seconds ---
# State confirmed as Florida
# 422 26 FL_CharlotteCounty.json
# --- 0.7650988101959229 seconds ---
# State confirmed as Florida
# 423 26 FL_CharlotteCounty.json
# --- 0.7950074672698975 seconds ---
# State confirmed as Florida
# 424 65 FL_DeSotoCounty.json
# --- 0.7655744552612305 seconds ---
# State confirmed as Florida
# 425 26 FL_CharlotteCounty.json
# --- 0.7661547660827637 seconds ---
# State confirmed as Florida
# 426 65 FL_DeSotoCounty.json
# --- 0.765845775604248 seconds ---
# State confirmed as Florida
# 427 26 FL_CharlotteCounty.json
# --- 0.7658295631408691 seconds ---
# State confirmed as Florida
# 428 65 FL_DeSotoCounty.json
# --- 0.7897689342498779 seconds ---
# State confirmed as Florida
# 429 29 FL_HighlandsCounty.json
# --- 0.7738852500915527 seconds ---
# State confirmed as Florida
# 430 65 FL_DeSotoCounty.json
# --- 0.76967453956604 seconds ---
# State confirmed as Florida
# 431 65 FL_DeSotoCounty.json
# --- 0.7659077644348145 seconds ---
# State confirmed as Florida
# 432 65 FL_DeSotoCounty.json
# --- 0.7935647964477539 seconds ---
# State confirmed as Florida
# 433 65 FL_DeSotoCounty.json
# --- 0.7665457725524902 seconds ---
# State confirmed as Florida
# 434 65 FL_DeSotoCounty.json
# --- 0.7655625343322754 seconds ---
# State confirmed as Florida
# 435 65 FL_DeSotoCounty.json
# --- 0.7657642364501953 seconds ---
# State confirmed as Florida
# 436 29 FL_HighlandsCounty.json
# --- 0.8016717433929443 seconds ---
# State confirmed as Florida
# 437 24 FL_OkeechobeeCounty.json
# --- 0.7721731662750244 seconds ---
# State confirmed as Florida
# 438 24 FL_OkeechobeeCounty.json
# --- 0.7713792324066162 seconds ---
# State confirmed as Florida
# 439 24 FL_OkeechobeeCounty.json
# --- 0.7698123455047607 seconds ---
# State confirmed as Florida
# 440 24 FL_OkeechobeeCounty.json
# --- 0.809931755065918 seconds ---
# State confirmed as Florida
# 441 29 FL_HighlandsCounty.json
# --- 0.7824428081512451 seconds ---
# State confirmed as Florida
# 442 29 FL_HighlandsCounty.json
# --- 0.775761604309082 seconds ---
# State confirmed as Florida
# 443 24 FL_OkeechobeeCounty.json
# --- 0.8012280464172363 seconds ---
# State confirmed as Florida
# 444 55 FL_MartinCounty.json
# --- 0.7686135768890381 seconds ---
# State confirmed as Florida
# 445 44 FL_PalmBeachCounty.json
# --- 0.7758572101593018 seconds ---
# State confirmed as Florida
# 446 44 FL_PalmBeachCounty.json
# --- 0.7778615951538086 seconds ---
# State confirmed as Florida
# 447 55 FL_MartinCounty.json
# --- 0.7656502723693848 seconds ---
# State confirmed as Florida
# 448 55 FL_MartinCounty.json
# --- 0.7937917709350586 seconds ---
# State confirmed as Florida
# 449 24 FL_OkeechobeeCounty.json
# --- 0.777564525604248 seconds ---
# State confirmed as Florida
# 450 65 FL_DeSotoCounty.json
# --- 0.7701504230499268 seconds ---
# State confirmed as Florida
# 451 44 FL_PalmBeachCounty.json
# --- 0.7668657302856445 seconds ---
# State confirmed as Florida
# 452 44 FL_PalmBeachCounty.json
# --- 0.7648310661315918 seconds ---
# State confirmed as Florida
# 453 44 FL_PalmBeachCounty.json
# --- 0.7931768894195557 seconds ---
# State confirmed as Florida
# 454 44 FL_PalmBeachCounty.json
# --- 0.765855073928833 seconds ---
# State confirmed as Florida
# 455 44 FL_PalmBeachCounty.json
# --- 0.7702052593231201 seconds ---
# State confirmed as Florida
# 456 44 FL_PalmBeachCounty.json
# --- 0.7700603008270264 seconds ---
# State confirmed as Florida
# 457 44 FL_PalmBeachCounty.json
# --- 0.7943089008331299 seconds ---
# State confirmed as Florida
# 458 44 FL_PalmBeachCounty.json
# --- 0.7683627605438232 seconds ---
# State confirmed as Florida
# 459 44 FL_PalmBeachCounty.json
# --- 0.7839875221252441 seconds ---
# State confirmed as Florida
# 460 44 FL_PalmBeachCounty.json
# --- 0.7711000442504883 seconds ---
# State confirmed as Florida
# 461 44 FL_PalmBeachCounty.json
# --- 0.7958624362945557 seconds ---
# State confirmed as Florida
# 462 14 FL_HendryCounty.json
# --- 0.7692148685455322 seconds ---
# State confirmed as Florida
# 463 14 FL_HendryCounty.json
# --- 0.7715704441070557 seconds ---
# State confirmed as Florida
# 464 14 FL_HendryCounty.json
# --- 0.7686560153961182 seconds ---
# State confirmed as Florida
# 465 14 FL_HendryCounty.json
# --- 0.7672579288482666 seconds ---
# State confirmed as Florida
# 466 14 FL_HendryCounty.json
# --- 0.796811580657959 seconds ---
# State confirmed as Florida
# 467 14 FL_HendryCounty.json
# --- 0.7697112560272217 seconds ---
# State confirmed as Florida
# 468 14 FL_HendryCounty.json
# --- 0.7681088447570801 seconds ---
# State confirmed as Florida
# 469 14 FL_HendryCounty.json
# --- 0.7688560485839844 seconds ---
# State confirmed as Florida
# 470 14 FL_HendryCounty.json
# --- 0.792804479598999 seconds ---
# State confirmed as Florida
# 471 14 FL_HendryCounty.json
# --- 0.7691895961761475 seconds ---
# State confirmed as Florida
# 472 14 FL_HendryCounty.json
# --- 0.7693133354187012 seconds ---
# State confirmed as Florida
# 473 44 FL_PalmBeachCounty.json
# --- 0.7692780494689941 seconds ---
# State confirmed as Florida
# 474 14 FL_HendryCounty.json
# --- 0.7717032432556152 seconds ---
# State confirmed as Florida
# 475 14 FL_HendryCounty.json
# --- 0.8119380474090576 seconds ---
# State confirmed as Florida
# 476 14 FL_HendryCounty.json
# --- 0.772425651550293 seconds ---
# State confirmed as Florida
# 477 14 FL_HendryCounty.json
# --- 0.7713837623596191 seconds ---
# State confirmed as Florida
# 478 34 FL_BrowardCounty.json
# --- 0.7672195434570312 seconds ---
# State confirmed as Florida
# 479 14 FL_HendryCounty.json
# --- 0.7980642318725586 seconds ---
# State confirmed as Florida
# 480 1 FL_Miami-DadeCounty.json
# --- 0.7710812091827393 seconds ---
# State confirmed as Florida
# 481 1 FL_Miami-DadeCounty.json
# --- 0.7734551429748535 seconds ---
# State confirmed as Florida
# 482 1 FL_Miami-DadeCounty.json
# --- 0.772759199142456 seconds ---
# State confirmed as Florida
# 483 34 FL_BrowardCounty.json
# --- 0.7687532901763916 seconds ---
# State confirmed as Florida
# 484 1 FL_Miami-DadeCounty.json
# --- 0.7974913120269775 seconds ---
# State confirmed as Florida
# 485 34 FL_BrowardCounty.json
# --- 0.7702305316925049 seconds ---
# State confirmed as RhodeIsland
# 486 3 RI_KentCounty.json
# --- 0.4787890911102295 seconds ---
# State confirmed as RhodeIsland
# 487 3 RI_KentCounty.json
# --- 0.4785308837890625 seconds ---
# State confirmed as RhodeIsland
# 488 3 RI_KentCounty.json
# --- 0.478668212890625 seconds ---
# State confirmed as RhodeIsland
# 489 3 RI_KentCounty.json
# --- 0.47853660583496094 seconds ---
# State confirmed as California
# 490 43 CA_RiversideCounty.json
# --- 0.9403908252716064 seconds ---
# State confirmed as California
# 491 43 CA_RiversideCounty.json
# --- 0.9710259437561035 seconds ---
# State confirmed as California
# 492 43 CA_RiversideCounty.json
# --- 0.943859338760376 seconds ---
# State confirmed as California
# 493 43 CA_RiversideCounty.json
# --- 0.9418065547943115 seconds ---
# State confirmed as California
# 494 43 CA_RiversideCounty.json
# --- 0.94175124168396 seconds ---
# State confirmed as California
# 495 43 CA_RiversideCounty.json
# --- 0.9674837589263916 seconds ---
# State confirmed as California
# 496 43 CA_RiversideCounty.json
# --- 0.9396138191223145 seconds ---
# State confirmed as California
# 497 43 CA_RiversideCounty.json
# --- 0.9406983852386475 seconds ---
# State confirmed as California
# 498 43 CA_RiversideCounty.json
# --- 0.9404623508453369 seconds ---

# %%
state_polygon

# %%
polygon

# %%
locations[498]

# %%
boundary

# %%
####################################################################################################################

# %% [markdown]
# ## Some plotting routines

# %%
for i in range(0, len(county_centers)):
    plt.plot(county_centers[i,1], county_centers[i,0], 'ro')

plt.axis('equal')
plt.show()

# %%
for i in range(0, 50):
    plt.plot(state_centers[i,1], state_centers[i,0], 'ro')

plt.axis('equal')
plt.show()

# %%
locations[0]

# %%
for n in range(0, 50):
    
    print(names[n], abbrv[n])
    county_files = os.listdir('/Users/samtaimourzadeh/python/dev/osm/boundary_data/counties')

    counties = [s for s in county_files if abbrv[n] in s]

    plt.figure(figsize=(11,11))
    error_array1 = []
    error_array2 = []
    error_array3 = []
    error_array4 = []

    group1 = []
    group2 = []
    group3 = []
    group4 = []
    path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/counties/'

    #for i in range(59, 60):#len(counties)):
    for i in range(0, len(counties)):
        try:
            # path for boundary json file
            json_data=open(path+counties[i], 'r')
            boundary = json.load(json_data)
            #nb = len(boundary)
            if nb==2:
                for m in range(nb):
                    polygon = boundary[m]['geojson']['coordinates']
                    polygon_ar = np.asarray(polygon)[0]
                    plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            else:
                polygon = boundary['geojson']['coordinates']
                polygon_ar = np.asarray(polygon)[0]
                plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            #polygon = boundary['geojson']['coordinates']
            #polygon_ar = np.asarray(polygon)[0]
            #plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group1.append(i)
        except:
            error_array1.append(i)
    for i in error_array1:
        try:
            # path for boundary json file
            json_data=open(path+counties[i], 'r')
            boundary = json.load(json_data)
            num = len(boundary['geojson']['coordinates'])
            for n in range(num):
                polygon = boundary['geojson']['coordinates'][n]
                polygon_ar = np.asarray(polygon)[0]
                plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group2.append(i)
        except:
            error_array2.append(i)
    for i in error_array2:
        try:
            # path for boundary json file
            json_data=open(path+counties[i], 'r')
            boundary = json.load(json_data)
            num = len(boundary['geojson']['coordinates'])
            for n in range(num):
                polygon = boundary['geojson']['coordinates'][n]
                polygon_ar = np.asarray(polygon[0])
                plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group3.append(i)
        except:
            error_array3.append(i)
    for i in error_array3:
        try:
            # path for boundary json file
            json_data=open(path+counties[i], 'r')
            boundary = json.load(json_data)
            nb = len(boundary)
            for m in range(nb):
                polygon = boundary['geojson']['coordinates']
                polygon_ar = np.asarray(polygon[0])
                plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
            group4.append(i)
        except:
            error_array4.append(i)
    plt.axis('equal')



    #plt.xlim(-130, -65)
    #plt.ylim(25, 50)

    #plt.xlim(-95, -80)
    #plt.ylim(29, 36)
    #plt.plot(michigan_ar[:,0], michigan_ar[:,1],'k')

    plt.axis('equal')
    plt.show()

# %%
plt.figure(figsize=(11,11))
error_array1 = []
error_array2 = []
error_array3 = []
error_array4 = []

group1 = []
group2 = []
group3 = []
group4 = []

for i in range(0, len(names)):
    try:
        # path for boundary json file
        path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
        json_data=open(path+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon)[0]
        plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        group1.append(i)
    except:
        error_array1.append(i)
for i in error_array1:
    try:
        # path for boundary json file
        path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
        json_data=open(path+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon[0])[0]
        plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        group2.append(i)

    except:
        error_array2.append(i)
for i in error_array2:
    try:
        # path for boundary json file
        path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
        json_data=open(path+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon[0])
        plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        group3.append(i)

    except:
        error_array3.append(i)
for i in error_array3:
    try:
        # path for boundary json file
        path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
        json_data=open(path+names[i]+'.json', 'r')
        boundary = json.load(json_data)
        polygon = boundary['geojson']['coordinates']
        polygon_ar = np.asarray(polygon[0])
        plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')
        group4.append(i)

    except:
        error_array4.append(i)

# path for boundary json file
# kentucky has two boundries
path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
json_data=open(path+names[16]+'.json', 'r')
boundary = json.load(json_data)
polygon = boundary['geojson']['coordinates']
polygon_ar = np.asarray(polygon[1])[0]
plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')

#Michigan
#path = '/Users/samtaimourzadeh/python/dev/osm/boundary_data/states/'
#json_data=open(path+names[21]+'.json', 'r')
#boundary = json.load(json_data)
#polygon = boundary['geojson']['coordinates']
#polygon_ar = np.asarray(polygon[0])
#plt.fill(polygon_ar[:,0],polygon_ar[:,1],'k', edgecolor='w')

plt.axis('equal')
plt.xlim(-130, -65)
plt.ylim(25, 50)
plt.show()

# %%
names[10]

# %%
group2

# %%
spec_df
